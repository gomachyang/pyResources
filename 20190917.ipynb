# %%
from bs4 import BeautifulSoup as bs

# %%
import urllib3 as url

# %%
content = url.get_host('https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/')

# %%
content
# Out:
# ('https', 'blog.gtwang.org', None)

# %%
content.count
# Out:
# <function tuple.count(value, /)>

# %%
## Get Post Put Delete CRUD

# %%
http = url.PoolManager()
r = http.request('GET', 'https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/')
# Out:
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
type(r)
# Out:
# urllib3.response.HTTPResponse

# %%
r

# %%
r.data
# Out:
# b'<!DOCTYPE html>\r\n<html class="no-js" lang="zh-TW">\r\n\t<head profile="http://gmpg.org/xfn/11">\r\n\t\t<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\r\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0" >\r\n\t\t<title>Python \xe4\xbd\xbf\xe7\x94\xa8 Beautiful Soup \xe6\x8a\x93\xe5\x8f\x96\xe8\x88\x87\xe8\xa7\xa3\xe6\x9e\x90\xe7\xb6\xb2\xe9\xa0\x81\xe8\xb3\x87\xe6\x96\x99\xef\xbc\x8c\xe9\x96\x8b\xe7\x99\xbc\xe7\xb6\xb2\xe8\xb7\xaf\xe7\x88\xac\xe8\x9f\xb2\xe6\x95\x99\xe5\xad\xb8 - G. T. Wang</title>\n<script>document.documentElement.className = document.documentElement.className.replace("no-js","js");</script>\n\n<!-- This site is optimized with the Yoast SEO plugin v12.0 - https://yoast.com/wordpress/plugins/seo/ -->\n<link rel="canonical" href="https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/" />\n<link rel="next" href="https://blog.gtwang.org/programming/python-beautiful
# ...

# %%
soup = bs(r.data, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="zh-TW">
# <head profile="http://gmpg.org/xfn/11">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <title>Python 使用 Beautiful Soup 抓取與解析網頁資料，開發網路爬蟲教學 - G. T. Wang</title>
# <script>document.documentElement.className = document.documentElement.className.replace("no-js","js");</script>
# <!-- This site is optimized with the Yoast SEO plugin v12.0 - https://yoast.com/wordpress/plugins/seo/ -->
# <link href="https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/" rel="canonical"/>
# <link href="https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/2/" rel="next"/>
# <meta content="zh_TW" property="og:locale">
# <meta content="article" property="og:type"/>
# <meta content="Python 使用 Beautiful Soup 抓取與解析網頁資料，開發網路爬蟲教學 - G. T. Wang" property="og:title"/>
# ...

# %%
amnh = url.PoolManager()
amp = amnh.request('GET', 'http://research.amnh.org/vz/herpetology/amphibia/')

# %%
amp

# %%
soup_amnh = bs(amp.data, 'html.parser')

# %%
soup_amnh
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="Category: Herpetology" name="WT.cg_n">
# <meta content="SubCat: Amphibian Species of the World" name="WT.cg_s"/>
# <title>Amphibian Species of the World</title>
# <link as="font" crossorigin="anonymous" href="/vz/herpetology/amphibia/extension/amphib/design/amphib/fonts/sofiapro/sofiapro-regular-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/vz/herpetology/amphibia/extension/amphib/design/amphib/fonts/sofiapro/sofiapro-medium-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/vz/herpetology/amphibia/extension/amphib/design/amphib/fonts/sofiapro/sofiapro-light-webfont.woff2" rel="preload" type="font/woff2"/>
# ...

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="no-js" lang="zh-TW">
# <head profile="http://gmpg.org/xfn/11">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <title>Python 使用 Beautiful Soup 抓取與解析網頁資料，開發網路爬蟲教學 - G. T. Wang</title>
# <script>document.documentElement.className = document.documentElement.className.replace("no-js","js");</script>
# <!-- This site is optimized with the Yoast SEO plugin v12.0 - https://yoast.com/wordpress/plugins/seo/ -->
# <link href="https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/" rel="canonical"/>
# <link href="https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/2/" rel="next"/>
# <meta content="zh_TW" property="og:locale">
# <meta content="article" property="og:type"/>
# ...

# %%
title = soup.title.string

# %%
title
# Out:
# 'Python 使用 Beautiful Soup 抓取與解析網頁資料，開發網路爬蟲教學 - G. T. Wang'

# %%
soup_amnh.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <meta content="Category: Herpetology" name="WT.cg_n">
# <meta content="SubCat: Amphibian Species of the World" name="WT.cg_s"/>
# <title>Amphibian Species of the World</title>
# <link as="font" crossorigin="anonymous" href="/vz/herpetology/amphibia/extension/amphib/design/amphib/fonts/sofiapro/sofiapro-regular-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/vz/herpetology/amphibia/extension/amphib/design/amphib/fonts/sofiapro/sofiapro-medium-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/vz/herpetology/amphibia/extension/amphib/design/amphib/fonts/sofiapro/sofiapro-light-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/vz/herpetology/amphibia/extension/amphib/design/amphib/fonts/sofiapro/sofiapro-semibold-webfont.woff2" rel="preload" type="font/woff2"/>
# ...

# %%
a_tags = soup.find_all('a')

# %%
len(a_tags)
# Out:
# 81

# %%
for _ in a_tags :
    print(_.string)
# Out:
# Blogger 舊站
# 關於
# Facebook
# Flickr
# None
# 物聯網
# 網站架設
# 程式設計
# 統計
# 素食
# 特價優惠
# 宗教
# 物聯網
# 網站架設
# 程式設計
# 統計
# 素食
# 特價優惠
# 宗教
# Python 使用 Beautiful Soup 抓取與解析網頁資料，開發網路爬蟲教學
# None
# None
# Beautiful Soup
# Beautiful Soup 官方的說明文件
# 2
# 3
# 程式設計
# Python
# 網路
# None
# G. T. Wang
# None
# Add Comment →
# 2019/03/26
# Reply
# 2019/05/06
# Reply
# 2019/08/09
# Reply
# 從範例學程式進階 – Python(1080808-09) | 碧華國小資訊中心
# 取消回覆
# Coursera 線上教學課程
# Udemy 線上教學課程
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 如何戒邪淫、遠離婚外情
# 戒淫寶典：《壽康寶鑑》白話有聲書
# igiving 公益網
# Yahoo 奇摩公益
# 社團法人新竹縣愛心物資集發協會
# 智邦公益網
# 台灣世界展望會
# G. T. Wang

# %%
p_tags = soup.find_all('p')

# %%
for _ in p_tags :
    print(_.string)
# Out:
# 這裡介紹如何使用 Python 的 Beautiful Soup 模組自動下載並解析網頁資料，開發典型的網路爬蟲程式。
# None
# None
# 在 Ubuntu Linux 中亦可使用 apt 安裝：
# None
# 以下是一個簡單的小程式，示範如何使用 Beautiful Soup 模組解析原始的 HTML 程式碼：
# None
# 首先我們可以將完整個 HTML 結構經過排版後輸出，觀察整份文件的輪廓：
# None
# None
# None
# None
# 若要同時搜尋多種 HTML 標籤，可以使用 list 來指定所有的要列出的 HTML 標籤名稱：
# None
# None
# None
# None
# 接下來我們要介紹一些更詳細的使用方式，請繼續閱讀下一頁。
# None
# None
# 個人使用 Linux 經驗長達十餘年，樂於分享各種自由軟體技術與實作文章。
# None
# None
# 很多地方都只是写prettify()可以把代码格式化。。。解释得一点都不通俗，还是不明白。你解释得清楚多了，一目了然！谢谢！
# None
# None
# None
# None
# None
# None
# None

# %%
link_tags = soup.find_all('link')

# %%
for _ in link_tags :
    print(_.get('href'))
# Out:
# https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/
# https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/2/
# https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/amp/
# //s.w.org
# https://blog.gtwang.org/feed/
# https://blog.gtwang.org/comments/feed/
# https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/feed/
# https://blog.gtwang.org/wp-includes/css/dist/block-library/style.min.css?ver=5.2.3
# https://blog.gtwang.org/wp-content/themes/rowling/fa/css/font-awesome.min.css?ver=5.2.3
# https://blog.gtwang.org/wp-content/themes/rowling/style.min.css?ver=5.2.3
# https://blog.gtwang.org/wp-json/
# https://blog.gtwang.org/xmlrpc.php?rsd
# https://blog.gtwang.org/wp-includes/wlwmanifest.xml
# https://blog.gtwang.org/?p=37241
# ...
