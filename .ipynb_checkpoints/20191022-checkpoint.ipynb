# %%
# !pip install selenium
# Out:
# ...
#     100% |████████████████████████████████| 911kB 14.0MB/s
# ...

# %%
chrome = '/Users/diploderma/Downloads/chromedriver'

# %%
from selenium import webdriver
driver = webdriver.Chrome(chrome)
driver.get("https://www.google.com")

# %%
goodluck = driver.find_element_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[3]/center/input[2]')
goodluck.click()

# %%
searchbox = driver.find_element_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[1]/div/div[2]/input')
searchbox.send_keys('weather')
searchbox.submit()

# %%
content = driver.page_source

# %%
content
# Out:
# '<html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="zh-TW"><head><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><meta content="origin" name="referrer"><title>weather - Google 搜尋</title><script src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.7kWSr24wXFc.O/m=gapi_iframes,googleapis_client,plusone/rt=j/sv=1/d=1/ed=1/rs=AHpOoo-i9r7IbCTUQfJ0v-FPhRKRS8aihQ/cb=gapi.loaded_0" nonce="eshZHKfcNdWhvqdDRD9r8A==" async=""></script><script nonce="eshZHKfcNdWhvqdDRD9r8A==">(function(){window.google={kEI:\'lO2uXYq5CqzemAWiyJTgBQ\',kEXPI:\'31\',authuser:0,kscs:\'c9c918f0_lO2uXYq5CqzemAWiyJTgBQ\',kGL:\'TW\',kBL:\'cXSl\'};google.sn=\'web\';google.kHL=\'zh-TW\';google.jsfs=\'Ffpdje\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttr
# ...

# %%
from bs4 import BeautifulSoup as bs

# %%
google = bs(content, 'html.parser')

# %%
print (google.prettify())
# Out:
# <html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="zh-TW">
#  <head>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <meta content="origin" name="referrer"/>
#   <title>
#    weather - Google 搜尋
#   </title>
#   <script async="" nonce="eshZHKfcNdWhvqdDRD9r8A==" src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.7kWSr24wXFc.O/m=gapi_iframes,googleapis_client,plusone/rt=j/sv=1/d=1/ed=1/rs=AHpOoo-i9r7IbCTUQfJ0v-FPhRKRS8aihQ/cb=gapi.loaded_0">
#   </script>
#   <script nonce="eshZHKfcNdWhvqdDRD9r8A==">
# ...
