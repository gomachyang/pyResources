# %%
import pandas as pd
import os 
import re
import sys

# %%
# xl_content = pd.read_excel('20190806_python_club_pandas_demo_data.xlsx')

# %%
# xl_content

# %%
for _ in os.listdir('./') :
    if _.endswith('xlsx') :
        print(_)
# Out:
# 20190806_python_club_pandas_demo_data.xlsx

# %%
# read data using pandas

# %%
import pandas as pd

# %%
# step 1 read data 

data_path = './20190806_python_club_pandas_demo_data.xlsx'

data_object = pd.read_excel(data_path)

# %%
# not using
# shift + tab

data_object_1 = pd.read_excel(data_path, index_col='gene')

# %%
type(data_object)
# Out:
# pandas.core.frame.DataFrame

# %%
data_object.head()
# Out:
#                     run.name sample.name     type   gene    chr     start  \
# 0  Proton_B_48_IonXpress_014      B00246  Serous   PGAP3  chr17  37829249
# 1  Proton_B_48_IonXpress_014      B00246  Serous    CRKL  chr22  21272220
# 2  Proton_B_48_IonXpress_014      B00246  Serous   BUB1B  chr15  40453332
# 3  Proton_B_48_IonXpress_014      B00246  Serous   STK11  chr19   1206845
# 4  Proton_B_48_IonXpress_014      B00246  Serous    MEN1  chr11  64571750
#
#         end tumor purity copy.number copy*purity       ...         \
# 0  37844307        30.0%           2           2       ...
# 1  21304221          NaN           2           2       ...
# 2  40512974        30.0%         1.5         1.5       ...
# 3   1223244        30.0%           2           2       ...
# 4  64577547        30.0%           3           3       ...
#
#                                 comments  amplicon.total amplicon.final  \
# 0    p-value_correction=0.64177792041869              15             12
# ...

# %%
data_object.tail()
# Out:
#                         run.name sample.name     type     gene    chr  \
# 39259  Proton_B_77_IonXpress_043      B00251  Serous      BAP1   chr3
# 39260  Proton_B_77_IonXpress_043      B00251  Serous      SDHB   chr1
# 39261  Proton_B_77_IonXpress_043      B00251  Serous      ATF1  chr12
# 39262  Proton_B_77_IonXpress_043      B00251  Serous      SDHD  chr11
# 39263  Proton_B_77_IonXpress_043      B00251  Serous   PRKAR1A  chr17
#
#            start        end    tumor purity copy.number copy*purity  \
# 39259   52436209   52443884             NaN           2           2
# 39260   17345298   17380566             NaN         1.5         1.5
# 39261   51173949   51213477  66.3812742265%         1.5         1.5
# 39262  111957588  111965599             NaN           2           2
# 39263   66511460   66526627             NaN         1.5         1.5
#
#             ...                                                  comments  \
# ...

# %%
# read data using open or with open

# %%
# it will fail
with open(data_path, 'r') as rf :
    data_content = rf.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-25-4fa25a370efb> in <module>
#       1 # it will fail
#       2 with open(data_path, 'r') as rf :
# ----> 3     data_content = rf.read()
#
# /anaconda3/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xde in position 16: invalid continuation byte

# %%
# how many rows, columes in this dataframe
row = data_object.shape[0]
col = data_object.shape[1]
print (row, col)
# Out:
# 39264 27

# %%
data_object.head()
# Out:
#                     run.name sample.name     type   gene    chr     start  \
# 0  Proton_B_48_IonXpress_014      B00246  Serous   PGAP3  chr17  37829249
# 1  Proton_B_48_IonXpress_014      B00246  Serous    CRKL  chr22  21272220
# 2  Proton_B_48_IonXpress_014      B00246  Serous   BUB1B  chr15  40453332
# 3  Proton_B_48_IonXpress_014      B00246  Serous   STK11  chr19   1206845
# 4  Proton_B_48_IonXpress_014      B00246  Serous    MEN1  chr11  64571750
#
#         end tumor purity copy.number copy*purity       ...         \
# 0  37844307        30.0%           2           2       ...
# 1  21304221          NaN           2           2       ...
# 2  40512974        30.0%         1.5         1.5       ...
# 3   1223244        30.0%           2           2       ...
# 4  64577547        30.0%           3           3       ...
#
#                                 comments  amplicon.total amplicon.final  \
# 0    p-value_correction=0.64177792041869              15             12
# ...

# %%
data_object.columns.tolist()
# Out:
# ['run.name',
#  'sample.name',
#  'type',
#  'gene',
#  'chr',
#  'start',
#  'end',
#  'tumor purity',
#  'copy.number',
#  'copy*purity',
#  'LOH/HET',
#  'SNP#',
#  'LOH/HET count',
#  'SNP status',
#  'SNP_loc',
#  'p.value',
#  'q.values',
#  'comments',
#  'amplicon.total',
#  'amplicon.final',
#  'cytoband',
#  'role',
#  'Haplo_SI',
#  'BRCAness',
#  'ACT_pathway',
#  'mycancergenome_pathway',
#  'other.gene.name']

# %%
data_object.index
# Out:
# RangeIndex(start=0, stop=39264, step=1)

# %%
data_object_1.head()
# Out:
#                         run.name sample.name     type    chr     start  \
# gene
# PGAP3  Proton_B_48_IonXpress_014      B00246  Serous   chr17  37829249
# CRKL   Proton_B_48_IonXpress_014      B00246  Serous   chr22  21272220
# BUB1B  Proton_B_48_IonXpress_014      B00246  Serous   chr15  40453332
# STK11  Proton_B_48_IonXpress_014      B00246  Serous   chr19   1206845
# MEN1   Proton_B_48_IonXpress_014      B00246  Serous   chr11  64571750
#
#             end tumor purity copy.number copy*purity LOH/HET       ...        \
# gene                                                               ...
# PGAP3  37844307        30.0%           2           2     LOH       ...
# CRKL   21304221          NaN           2           2     NaN       ...
# BUB1B  40512974        30.0%         1.5         1.5     LOH       ...
# STK11   1223244        30.0%           2           2     HET       ...
# MEN1   64577547        30.0%           3           3     LOH       ...
#
# ...

# %%
data_object_1.index
# Out:
# Index(['PGAP3', 'CRKL', 'BUB1B', 'STK11', 'MEN1', 'USP9X', 'IL6ST', 'LIFR',
#        'CDC73', 'PIK3CA',
#        ...
#        'PLEKHG5', 'PTPRD', 'BRAF', 'GNA11', 'SDHA', 'BAP1', 'SDHB', 'ATF1',
#        'SDHD', 'PRKAR1A'],
#       dtype='object', name='gene', length=39264)

# %%
data_object['sample.name']
# Out:
# 0        B00246
# 1        B00246
# 2        B00246
# 3        B00246
# 4        B00246
# 5        B00246
# 6        B00246
# 7        B00246
# 8        B00246
# 9        B00246
# 10       B00246
# 11       B00246
# 12       B00246
# 13       B00246
# 14       B00246
# 15       B00246
# 16       B00246
# 17       B00246
# 18       B00246
# 19       B00246
# 20       B00246
# 21       B00246
# 22       B00246
# 23       B00246
# 24       B00246
# 25       B00246
# 26       B00246
# 27       B00246
# 28       B00246
# 29       B00246
#           ...
# 39234    B00251
# 39235    B00251
# 39236    B00251
# 39237    B00251
# 39238    B00251
# 39239    B00251
# 39240    B00251
# 39241    B00251
# 39242    B00251
# 39243    B00251
# 39244    B00251
# 39245    B00251
# 39246    B00251
# 39247    B00251
# 39248    B00251
# 39249    B00251
# 39250    B00251
# 39251    B00251
# 39252    B00251
# 39253    B00251
# 39254    B00251
# 39255    B00251
# 39256    B00251
# 39257    B00251
# ...

# %%
data_object.loc[0:10 , ['sample.name', 'gene']]
# Out:
#    sample.name    gene
# 0       B00246   PGAP3
# 1       B00246    CRKL
# 2       B00246   BUB1B
# 3       B00246   STK11
# 4       B00246    MEN1
# 5       B00246   USP9X
# 6       B00246   IL6ST
# 7       B00246    LIFR
# 8       B00246   CDC73
# 9       B00246  PIK3CA
# 10      B00246  PIK3CB

# %%
data_object_1.loc[0:10 , ['sample.name', 'gene']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-70bbc9e97f99> in <module>
# ----> 1 data_object_1.loc[0:10 , ['sample.name', 'gene']]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     888                 continue
#     889
# --> 890             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     891
#     892         return retval
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1864         if isinstance(key, slice):
# ...

# %%
data_object_1.index
# Out:
# Index(['PGAP3', 'CRKL', 'BUB1B', 'STK11', 'MEN1', 'USP9X', 'IL6ST', 'LIFR',
#        'CDC73', 'PIK3CA',
#        ...
#        'PLEKHG5', 'PTPRD', 'BRAF', 'GNA11', 'SDHA', 'BAP1', 'SDHB', 'ATF1',
#        'SDHD', 'PRKAR1A'],
#       dtype='object', name='gene', length=39264)

# %%
data_object_1.loc[['PIK3CA','BRAF'] , ['sample.name']]
# Out:
#        sample.name
# gene
# PIK3CA      B00246
# PIK3CA      B00432
# PIK3CA      B00266
# PIK3CA      B00290
# PIK3CA      B00303
# PIK3CA      B00263
# PIK3CA      B00290
# PIK3CA      B00283
# PIK3CA      B00257
# PIK3CA      B00268
# PIK3CA      B00420
# PIK3CA      B00270
# PIK3CA      B00239
# PIK3CA      B00302
# PIK3CA      B00431
# PIK3CA      B00269
# PIK3CA      B00281
# PIK3CA      B00286
# PIK3CA      B00426
# PIK3CA      B00267
# PIK3CA      B00298
# PIK3CA      B00439
# PIK3CA      B00278
# PIK3CA      B00263
# PIK3CA      B00255
# PIK3CA      B00430
# PIK3CA      B00437
# PIK3CA      B00299
# PIK3CA      B00245
# PIK3CA      B00261
# ...            ...
# BRAF        B00284
# BRAF        B00423
# BRAF        B00242
# BRAF        B00297
# BRAF        B00287
# BRAF        B00300
# BRAF        B00292
# BRAF        B00434
# BRAF        B00254
# BRAF        B00249
# BRAF        B00274
# BRAF        B00425
# BRAF        B00441
# BRAF        B00296
# BRAF        B00419
# ...

# %%
data_object.loc[ : ,]
# Out:
#                         run.name sample.name     type     gene    chr  \
# 0      Proton_B_48_IonXpress_014      B00246  Serous     PGAP3  chr17
# 1      Proton_B_48_IonXpress_014      B00246  Serous      CRKL  chr22
# 2      Proton_B_48_IonXpress_014      B00246  Serous     BUB1B  chr15
# 3      Proton_B_48_IonXpress_014      B00246  Serous     STK11  chr19
# 4      Proton_B_48_IonXpress_014      B00246  Serous      MEN1  chr11
# 5      Proton_B_48_IonXpress_014      B00246  Serous     USP9X   chrX
# 6      Proton_B_48_IonXpress_014      B00246  Serous     IL6ST   chr5
# 7      Proton_B_48_IonXpress_014      B00246  Serous      LIFR   chr5
# 8      Proton_B_48_IonXpress_014      B00246  Serous     CDC73   chr1
# 9      Proton_B_48_IonXpress_014      B00246  Serous    PIK3CA   chr3
# 10     Proton_B_48_IonXpress_014      B00246  Serous    PIK3CB   chr3
# 11     Proton_B_48_IonXpress_014      B00246  Serous    PIK3CD   chr1
# ...

# %%
col = ['type', 'gene', 'chr', 'start', 'end']
data_filter_by_gene = data_object.loc[ data_object.gene == 'BRAF' , 'type':'end' ]

# %%
# create a new colume

data_filter_by_gene['new type'] = data_filter_by_gene['type'].str.strip()

# %%
data_filter_by_gene
# Out:
#                type  gene   chr      start        end      new type
# 401         Serous   BRAF  chr7  140434389  140549943        Serous
# 810         Serous   BRAF  chr7  140434389  140549943        Serous
# 1219        Serous   BRAF  chr7  140434389  140549943        Serous
# 1628     Clear cell  BRAF  chr7  140434389  140549943    Clear cell
# 2037     Clear cell  BRAF  chr7  140434389  140549943    Clear cell
# 2446        Serous   BRAF  chr7  140434389  140549943        Serous
# 2855     Clear cell  BRAF  chr7  140434389  140549943    Clear cell
# 3264     Clear cell  BRAF  chr7  140434389  140549943    Clear cell
# 3673        Serous   BRAF  chr7  140434389  140549943        Serous
# 4082        Serous   BRAF  chr7  140434389  140549943        Serous
# 4491   endometrioid  BRAF  chr7  140434389  140549943  endometrioid
# 4900        Serous   BRAF  chr7  140434389  140549943        Serous
# 5309        Serous   BRAF  chr7  140434389  140549943        Serous
# ...

# %%
data_filter_by_gene.loc[data_filter_by_gene['new type'] == 'Serous', col]
# Out:
#           type  gene   chr      start        end
# 401    Serous   BRAF  chr7  140434389  140549943
# 810    Serous   BRAF  chr7  140434389  140549943
# 1219   Serous   BRAF  chr7  140434389  140549943
# 2446   Serous   BRAF  chr7  140434389  140549943
# 3673   Serous   BRAF  chr7  140434389  140549943
# 4082   Serous   BRAF  chr7  140434389  140549943
# 4900   Serous   BRAF  chr7  140434389  140549943
# 5309   Serous   BRAF  chr7  140434389  140549943
# 6536   Serous   BRAF  chr7  140434389  140549943
# 8172   Serous   BRAF  chr7  140434389  140549943
# 8990   Serous   BRAF  chr7  140434389  140549943
# 9808   Serous   BRAF  chr7  140434389  140549943
# 10217  Serous   BRAF  chr7  140434389  140549943
# 11853  Serous   BRAF  chr7  140434389  140549943
# 12262  Serous   BRAF  chr7  140434389  140549943
# 13489  Serous   BRAF  chr7  140434389  140549943
# 14307  Serous   BRAF  chr7  140434389  140549943
# 15125  Serous   BRAF  chr7  140434389  140549943
# ...

# %%
data_filter_by_gene.loc[ (data_filter_by_gene['new type'] == 'Serous') & (data_filter_by_gene['gene'] == 'BRAF') ]
# Out:
#           type  gene   chr      start        end new type
# 401    Serous   BRAF  chr7  140434389  140549943   Serous
# 810    Serous   BRAF  chr7  140434389  140549943   Serous
# 1219   Serous   BRAF  chr7  140434389  140549943   Serous
# 2446   Serous   BRAF  chr7  140434389  140549943   Serous
# 3673   Serous   BRAF  chr7  140434389  140549943   Serous
# 4082   Serous   BRAF  chr7  140434389  140549943   Serous
# 4900   Serous   BRAF  chr7  140434389  140549943   Serous
# 5309   Serous   BRAF  chr7  140434389  140549943   Serous
# 6536   Serous   BRAF  chr7  140434389  140549943   Serous
# 8172   Serous   BRAF  chr7  140434389  140549943   Serous
# 8990   Serous   BRAF  chr7  140434389  140549943   Serous
# 9808   Serous   BRAF  chr7  140434389  140549943   Serous
# 10217  Serous   BRAF  chr7  140434389  140549943   Serous
# 11853  Serous   BRAF  chr7  140434389  140549943   Serous
# 12262  Serous   BRAF  chr7  140434389  140549943   Serous
# ...

# %%
data_object.dtypes
# Out:
# run.name                   object
# sample.name                object
# type                       object
# gene                       object
# chr                        object
# start                      object
# end                        object
# tumor purity               object
# copy.number                object
# copy*purity                object
# LOH/HET                    object
# SNP#                      float64
# LOH/HET count              object
# SNP status                 object
# SNP_loc                    object
# p.value                    object
# q.values                   object
# comments                   object
# amplicon.total              int64
# amplicon.final              int64
# cytoband                   object
# role                       object
# Haplo_SI                   object
# BRCAness                   object
# ACT_pathway                object
# mycancergenome_pathway     object
# other.gene.name            object
# dtype: object

# %%
data_object.loc[data_object['amplicon.total'] > 30]
# Out:
#                         run.name sample.name     type      gene    chr  \
# 2      Proton_B_48_IonXpress_014      B00246  Serous      BUB1B  chr15
# 5      Proton_B_48_IonXpress_014      B00246  Serous      USP9X   chrX
# 6      Proton_B_48_IonXpress_014      B00246  Serous      IL6ST   chr5
# 7      Proton_B_48_IonXpress_014      B00246  Serous       LIFR   chr5
# 9      Proton_B_48_IonXpress_014      B00246  Serous     PIK3CA   chr3
# 10     Proton_B_48_IonXpress_014      B00246  Serous     PIK3CB   chr3
# 11     Proton_B_48_IonXpress_014      B00246  Serous     PIK3CD   chr1
# 12     Proton_B_48_IonXpress_014      B00246  Serous     PIK3CG   chr7
# 15     Proton_B_48_IonXpress_014      B00246  Serous      IGF1R  chr15
# 17     Proton_B_48_IonXpress_014      B00246  Serous      NUP98  chr11
# 18     Proton_B_48_IonXpress_014      B00246  Serous        XPC   chr3
# 20     Proton_B_48_IonXpress_014      B00246  Serous    PIK3C2B   chr1
# ...

# %%
data_object.sort_values(['amplicon.total', 'sample.name'], ascending=False)
# Out:
#                          run.name sample.name          type   gene   chr  \
# 15913   Proton_B_72_IonXpress_090      B00446  endometrioid  SYNE1  chr6
# 16731   Proton_B_72_IonXpress_089      B00445  endometrioid  SYNE1  chr6
# 23275  Proton_B_123_IonXpress_038      B00444  endometrioid  SYNE1  chr6
# 25729  Proton_B_130_IonXpress_038      B00444  endometrioid  SYNE1  chr6
# 13050  Proton_B_122_IonXpress_037      B00443  endometrioid  SYNE1  chr6
# 33909  Proton_B_122_IonXpress_036      B00442  endometrioid  SYNE1  chr6
# 32273  Proton_B_122_IonXpress_035      B00441  endometrioid  SYNE1  chr6
# 37590  Proton_B_122_IonXpress_034      B00440  endometrioid  SYNE1  chr6
# 8960   Proton_B_121_IonXpress_033      B00439       Serous   SYNE1  chr6
# 11005  Proton_B_121_IonXpress_032      B00437  endometrioid  SYNE1  chr6
# 36363   Proton_B_88_IonXpress_082      B00435  endometrioid  SYNE1  chr6
# 30228   Proton_B_85_IonXpress_081      B00434  endometrioid  SYNE1  chr6
# ...

# %%
data_object.fillna('0')
# Out:
#                         run.name sample.name     type     gene    chr  \
# 0      Proton_B_48_IonXpress_014      B00246  Serous     PGAP3  chr17
# 1      Proton_B_48_IonXpress_014      B00246  Serous      CRKL  chr22
# 2      Proton_B_48_IonXpress_014      B00246  Serous     BUB1B  chr15
# 3      Proton_B_48_IonXpress_014      B00246  Serous     STK11  chr19
# 4      Proton_B_48_IonXpress_014      B00246  Serous      MEN1  chr11
# 5      Proton_B_48_IonXpress_014      B00246  Serous     USP9X   chrX
# 6      Proton_B_48_IonXpress_014      B00246  Serous     IL6ST   chr5
# 7      Proton_B_48_IonXpress_014      B00246  Serous      LIFR   chr5
# 8      Proton_B_48_IonXpress_014      B00246  Serous     CDC73   chr1
# 9      Proton_B_48_IonXpress_014      B00246  Serous    PIK3CA   chr3
# 10     Proton_B_48_IonXpress_014      B00246  Serous    PIK3CB   chr3
# 11     Proton_B_48_IonXpress_014      B00246  Serous    PIK3CD   chr1
# ...

# %%
data_object['concate'] = data_object['sample.name'] + '_' + data_object['type'] + '_' + data_object['gene']

# %%
data_object
# Out:
#                         run.name sample.name     type     gene    chr  \
# 0      Proton_B_48_IonXpress_014      B00246  Serous     PGAP3  chr17
# 1      Proton_B_48_IonXpress_014      B00246  Serous      CRKL  chr22
# 2      Proton_B_48_IonXpress_014      B00246  Serous     BUB1B  chr15
# 3      Proton_B_48_IonXpress_014      B00246  Serous     STK11  chr19
# 4      Proton_B_48_IonXpress_014      B00246  Serous      MEN1  chr11
# 5      Proton_B_48_IonXpress_014      B00246  Serous     USP9X   chrX
# 6      Proton_B_48_IonXpress_014      B00246  Serous     IL6ST   chr5
# 7      Proton_B_48_IonXpress_014      B00246  Serous      LIFR   chr5
# 8      Proton_B_48_IonXpress_014      B00246  Serous     CDC73   chr1
# 9      Proton_B_48_IonXpress_014      B00246  Serous    PIK3CA   chr3
# 10     Proton_B_48_IonXpress_014      B00246  Serous    PIK3CB   chr3
# 11     Proton_B_48_IonXpress_014      B00246  Serous    PIK3CD   chr1
# ...

# %%
data_object['machine'] = data_object['run.name'].str.split('_').str[0:3].str.join('_').str.upper()

# %%
data_object.head()
# Out:
#                     run.name sample.name     type   gene    chr     start  \
# 0  Proton_B_48_IonXpress_014      B00246  Serous   PGAP3  chr17  37829249
# 1  Proton_B_48_IonXpress_014      B00246  Serous    CRKL  chr22  21272220
# 2  Proton_B_48_IonXpress_014      B00246  Serous   BUB1B  chr15  40453332
# 3  Proton_B_48_IonXpress_014      B00246  Serous   STK11  chr19   1206845
# 4  Proton_B_48_IonXpress_014      B00246  Serous    MEN1  chr11  64571750
#
#         end tumor purity copy.number copy*purity     ...      amplicon.final  \
# 0  37844307        30.0%           2           2     ...                  12
# 1  21304221          NaN           2           2     ...                  10
# 2  40512974        30.0%         1.5         1.5     ...                  44
# 3   1223244        30.0%           2           2     ...                  15
# 4  64577547        30.0%           3           3     ...                  18
#
# ...

# %%
type(data_object['run.name'])
# Out:
# pandas.core.series.Series
